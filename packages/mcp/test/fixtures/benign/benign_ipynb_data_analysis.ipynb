# %% [markdown]
# # Quarterly Sales Analysis
#
# Walk through revenue, units, and regional mix for Q4.

# %%
import pandas as pd
df = pd.read_csv('q4.csv')
df.head(3)
# Out:
#        region  revenue  units
# 0       North     1240    310
# 1       South      980    245
# 2        East     1100    270

# %%
total_revenue = df['revenue'].sum()
print(f'Total revenue: {total_revenue}')
