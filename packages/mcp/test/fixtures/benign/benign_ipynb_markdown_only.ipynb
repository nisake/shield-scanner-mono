# %% [markdown]
# # Project Notes
#
# Some headings and bullet points describing the work plan.
#
# - Pull the latest data dump.
# - Run the standard cleaning script.
# - Render the summary table.

# %% [markdown]
# ## References
#
# Internal wiki link omitted.
